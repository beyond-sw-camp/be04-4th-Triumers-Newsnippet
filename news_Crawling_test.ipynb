# %%
# import requests  # requests 라이브러리를 임포트합니다.

# # 웹훅 서버의 URL
# webhook_url = 'https://webhook.site/44802742-aee0-471b-bef7-44a901f35a2b'

# # 이전 코드에서 생성한 news_item 사용
# response = requests.post(webhook_url, json=news_item)
# print("서버 응답:", response.text)

# %%
from trafilatura import feeds, fetch_url, extract
import json
import feedparser
from bs4 import BeautifulSoup
import html  
import re
from datetime import datetime
import schedule
import time


def scheduled_fetch():
    feed_url = "https://newsis.com/RSS/international.xml"
    feed = feedparser.parse(feed_url)
    
    for entry in feed.entries:
        html_content = fetch_url(entry.link)  
        text_content = extract(html_content, output_format="json")
      
        news_date = datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
        news_link = entry.link
        title = html.unescape(entry.title).replace('\n', ' ')  
        content = html.unescape(entry.summary).replace('\n', ' ')
        content = re.sub(r'◎공감언론 뉴시스 [\w@.]+', '', content)
    
        # BeautifulSoup을 사용하여 content에서 HTML 태그 제거
        soup = BeautifulSoup(content, 'html.parser')
        cleaned_content = soup.get_text()
        
        # 카테고리
        category = "국제"
    
        news_item = {
                "newsDate": news_date,
                "newsLink": news_link,
                "title": title,
                "content": cleaned_content, 
                "category": category
            }
        print(json.dumps(news_item, ensure_ascii=False, indent=4))


schedule.every(1).minutes.do(scheduled_fetch)

while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# {
#     "newsDate": "2024-04-12",
#     "newsLink": "http://www.newsis.com/view/?id=NISX20240412_0002697661",
#     "title": "바다 한가운데 떠 있는 2층 주택…무슨 사연?",
#     "content": "[서울=뉴시스] 정혜승 인턴 기자 = 미국 서부 바다 한가운데서 발견된 2층 목조 주택의 정체가 드러났다. 11일(현지시각) 미 ABC7 등 현지 언론에 따르면 캘리포니아주 샌프란시스코 인근 바다에서 물 위에 떠 있는 2층 주택이 지난 7일 발견돼 큰 화제가 됐다. 발견 당시 이 집의 소유자나 항해 계획 등은 밝혀지지 않았다. 미 해안경비대(USCG)는 이 주택이 바지선 위에 지어졌으며, 이곳에서 민간 통행이 이뤄지는지 감시 중이라고 전했다. 나중에 이 집은 레드우드 시티 선착장의 마지막 '하우스 보트’인 것으로 드러났다. 이 선착장에서는 한때 100명 이상의 주민이 하우스 보트에 거주했다. 그러나 '통행을 불편하게 한다'는 인근 주민들의 반발로 2015년 하우스 보트들의 퇴거 조치가 시작됐다. 이때 수십 척의 하우스 보트가 이전했다고 매체는 전했다. 발견된 배 역시 샌프란시스코 소살리토 지역으로 가던 중 문제가 발생해 바다에 떠 있게 됐다. 집주인에 따르면 하우스 보트는 바람과 조수의 영향을 크게 받는다.이런 사연이 알려지자, 누리꾼들은 픽사의 영화 업(UP)에 나오는 집이 떠오른다는 반응을 보였다. ",
#     "category": "국제"
# }
# {
#     "newsDate": "2024-04-12",
#     "newsLink": "http://www.newsis.com/view/?id=NISX20240412_0002697771",
#     "title": "[속보] 중국 3월 수출 7.5%↓ 수입 1.9%↓",
# ...

# %%
from trafilatura import feeds, fetch_url, extract
import json
import feedparser
from bs4 import BeautifulSoup
import html  
import re
from datetime import datetime

feed_url = "https://www.newsis.com/RSS/bank.xml"
feed = feedparser.parse(feed_url)

for entry in feed.entries:
    html_content = fetch_url(entry.link)  
    text_content = extract(html_content, output_format="json")
  
    news_date = datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
    news_link = entry.link
    title = html.unescape(entry.title).replace('\n', ' ')  
    content = html.unescape(entry.summary).replace('\n', ' ')
    content = re.sub(r'◎공감언론 뉴시스 [\w@.]+', '', content)

    # BeautifulSoup을 사용하여 content에서 HTML 태그 제거
    soup = BeautifulSoup(content, 'html.parser')
    cleaned_content = soup.get_text()
    
    # 카테고리
    category = "금융"

    news_item = {
            "newsDate": news_date,
            "newsLink": news_link,
            "title": title,
            "content": cleaned_content, 
            "category": category
        }
    print(json.dumps(news_item, ensure_ascii=False, indent=4))
# Out:
# {
#     "newsDate": "2024-04-11",
#     "newsLink": "http://www.newsis.com/view/?id=NISX20240411_0002695563",
#     "title": "\"민주당 금융정책 살펴보니\"…전 국민 '최저생계비 계좌' 나오나",
# ...

# %%
from trafilatura import feeds, fetch_url, extract
import json
import feedparser
from bs4 import BeautifulSoup
import html  
import re
from datetime import datetime

feed_url = "https://www.newsis.com/RSS/society.xml"
feed = feedparser.parse(feed_url)

for entry in feed.entries:
    html_content = fetch_url(entry.link)  
    text_content = extract(html_content, output_format="json")
  
    news_date = datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
    news_link = entry.link
    title = html.unescape(entry.title).replace('\n', ' ')  
    content = html.unescape(entry.summary).replace('\n', ' ')
    content = re.sub(r'◎공감언론 뉴시스 [\w@.]+', '', content)

    # BeautifulSoup을 사용하여 content에서 HTML 태그 제거
    soup = BeautifulSoup(content, 'html.parser')
    cleaned_content = soup.get_text()
    
    # 카테고리
    category = "사회"

    news_item = {
            "newsDate": news_date,
            "newsLink": news_link,
            "title": title,
            "content": cleaned_content, 
            "category": category
        }
    print(json.dumps(news_item, ensure_ascii=False, indent=4))
# Out:
# {
#     "newsDate": "2024-04-11",
#     "newsLink": "http://www.newsis.com/view/?id=NISX20240411_0002695586",
#     "title": "UNIST, 크라우드소싱 기반으로 효율적 통합 배송 방법 개발",
# ...

# %%
from trafilatura import feeds, fetch_url, extract
import json
import feedparser
from bs4 import BeautifulSoup
import html  
import re
from datetime import datetime

feed_url = "https://www.newsis.com/RSS/politics.xml"
feed = feedparser.parse(feed_url)

for entry in feed.entries:
    html_content = fetch_url(entry.link)  
    text_content = extract(html_content, output_format="json")
  
    news_date = datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
    news_link = entry.link
    title = html.unescape(entry.title).replace('\n', ' ')  
    content = html.unescape(entry.summary).replace('\n', ' ')
    content = re.sub(r'◎공감언론 뉴시스 [\w@.]+', '', content)

    # BeautifulSoup을 사용하여 content에서 HTML 태그 제거
    soup = BeautifulSoup(content, 'html.parser')
    cleaned_content = soup.get_text()
    
    # 카테고리
    category = "정치"

    news_item = {
            "newsDate": news_date,
            "newsLink": news_link,
            "title": title,
            "content": cleaned_content, 
            "category": category
        }
    print(json.dumps(news_item, ensure_ascii=False, indent=4))
# Out:
# {
#     "newsDate": "2024-04-11",
#     "newsLink": "http://www.newsis.com/view/?id=NISX20240411_0002695604",
#     "title": "22대 총선 충남 최종 득표율(★당선인)",
#     "content": "[천안·아산=뉴시스]박우경 기자 = 충남 후보자별 득표현황(최종)★(당선)▲천안갑1.문진석(더불어민주당) 6만4562표 ★50.58%2.신범철(국민의힘) 6만178표 3.허욱(개혁신당) 2886표▲천안을1.이재관(더불어민주당) 5만8862표 ★55.12%2.이정만(국민의힘) 4만4628표3.전옥균(무소속) 3284표 ▲천안병1.이정문(더불어민주당) 5만4189표 ★55.2%2.이창수(국민의힘) 4만98표3.한정애(녹색정의당) 1364표4.이성진(개혁신당) 1700표▲공주시·부여군·청양군1.박수현(더불어민주당) 6만2635표 ★50.66%2.정진석(국민의힘) 5만9855표3.고주환(무소속) 1126▲보령시·서천군1.나소열(더불어민주당) 4만2802표 2.장동혁(국민의힘) 4만6505표 ★ 51.5%3.이기원(무소속) 521표4.장동호(무소속) 460표▲아산시갑1.복기왕(더불어민주당) 4만2153표 ★53.79%2.김영석(국민의힘) 3만4555표 3.조덕호(새로운미래) 1652표▲아산시을1.강훈식(더불어민주당) 5만8932표 ★60.35%2.전만권(국민의힘) 3만8716표 ▲서산시·태안군1.조한기(더불어민주당) 6만6222표 2.성일종(국민의힘) 7만487표 ★51.55%▲논산시·계룡시·금산군1.황명선(더불어민주당) 6만1146표 ★50.84%2.박성규(국민의힘) 5만6706표3.이창원(무소속) 2406표▲당진시1.어기구(더불어민주당) 4만6147표 ★51.78%2.정용선(국민의힘) 4만2983표▲홍성군·예산군1.양승조(더불어민주당) 4만6972표2.강승규(국민의힘) 5만7043표 ★54.84% ",
#     "category": "정치"
# }
# {
# ...

# %%
from trafilatura import feeds, fetch_url, extract
import json
import feedparser
from bs4 import BeautifulSoup
import html  
import re
from datetime import datetime

feed_url = "https://www.newsis.com/RSS/economy.xml"
feed = feedparser.parse(feed_url)

for entry in feed.entries:
    html_content = fetch_url(entry.link)  
    text_content = extract(html_content, output_format="json")
  
    news_date = datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
    news_link = entry.link
    title = html.unescape(entry.title).replace('\n', ' ')  
    content = html.unescape(entry.summary).replace('\n', ' ')
    content = re.sub(r'◎공감언론 뉴시스 [\w@.]+', '', content)

    # BeautifulSoup을 사용하여 content에서 HTML 태그 제거
    soup = BeautifulSoup(content, 'html.parser')
    cleaned_content = soup.get_text()
    
    # 카테고리
    category = "경제"

    news_item = {
            "newsDate": news_date,
            "newsLink": news_link,
            "title": title,
            "content": cleaned_content, 
            "category": category
        }
    print(json.dumps(news_item, ensure_ascii=False, indent=4))
# Out:
# {
#     "newsDate": "2024-04-11",
#     "newsLink": "http://www.newsis.com/view/?id=NISX20240409_0002694089",
#     "title": "나랏빚 1년새 59조 늘어 1100조 돌파…국민 1인당 2200만원[국가결산]",
# ...

# %%
from trafilatura import feeds, fetch_url, extract
import json
import feedparser
from bs4 import BeautifulSoup
import html  
import re
from datetime import datetime

feed_url = "https://www.newsis.com/RSS/industry.xml"
feed = feedparser.parse(feed_url)

for entry in feed.entries:
    html_content = fetch_url(entry.link)  
    text_content = extract(html_content, output_format="json")
  
    news_date = datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
    news_link = entry.link
    title = html.unescape(entry.title).replace('\n', ' ')  
    content = html.unescape(entry.summary).replace('\n', ' ')
    content = re.sub(r'◎공감언론 뉴시스 [\w@.]+', '', content)

    # BeautifulSoup을 사용하여 content에서 HTML 태그 제거
    soup = BeautifulSoup(content, 'html.parser')
    cleaned_content = soup.get_text()
    
    # 카테고리
    category = "산업"

    news_item = {
            "newsDate": news_date,
            "newsLink": news_link,
            "title": title,
            "content": cleaned_content, 
            "category": category
        }
    print(json.dumps(news_item, ensure_ascii=False, indent=4))
# Out:
# {
#     "newsDate": "2024-04-11",
#     "newsLink": "http://www.newsis.com/view/?id=NISX20240411_0002695594",
#     "title": "롯데백화점 부산본점서 전통 디저트 팝업 스토어 운영",
# ...

# %%
from trafilatura import feeds, fetch_url, extract
import json
import feedparser
from bs4 import BeautifulSoup
import html  
import re
from datetime import datetime

feed_url = "https://www.newsis.com/RSS/health.xml"
feed = feedparser.parse(feed_url)

for entry in feed.entries:
    html_content = fetch_url(entry.link)  
    text_content = extract(html_content, output_format="json")
  
    news_date = datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
    news_link = entry.link
    title = html.unescape(entry.title).replace('\n', ' ')  
    content = html.unescape(entry.summary).replace('\n', ' ')
    content = re.sub(r'◎공감언론 뉴시스 [\w@.]+', '', content)

    # BeautifulSoup을 사용하여 content에서 HTML 태그 제거
    soup = BeautifulSoup(content, 'html.parser')
    cleaned_content = soup.get_text()
    
    # 카테고리
    category = "IT·바이오"

    news_item = {
            "newsDate": news_date,
            "newsLink": news_link,
            "title": title,
            "content": cleaned_content, 
            "category": category
        }
    print(json.dumps(news_item, ensure_ascii=False, indent=4))
# Out:
# {
#     "newsDate": "2024-04-11",
#     "newsLink": "http://www.newsis.com/view/?id=NISX20240411_0002695586",
#     "title": "UNIST, 크라우드소싱 기반으로 효율적 통합 배송 방법 개발",
# ...

# %%
import requests
from trafilatura import feeds, fetch_url, extract
import json
import feedparser
from bs4 import BeautifulSoup
import html
import re
from datetime import datetime
import schedule
import time

def scheduled_fetch():
    # 웹훅 서버의 URL
    gpt_server_url = 'http://localhost:8130/quiz/generate'

    # 각 카테고리별 RSS 피드 URL
    categories = {
        "국제": "https://newsis.com/RSS/international.xml",
        "금융": "https://www.newsis.com/RSS/bank.xml",
        "사회": "https://www.newsis.com/RSS/society.xml",
        "정치": "https://www.newsis.com/RSS/politics.xml",
        "경제": "https://www.newsis.com/RSS/economy.xml",
        "산업": "https://www.newsis.com/RSS/industry.xml",
        "IT·바이오": "https://www.newsis.com/RSS/health.xml"
    }

    for category, feed_url in categories.items():
        feed = feedparser.parse(feed_url)
        
        for entry in feed.entries:
            html_content = fetch_url(entry.link)
            text_content = extract(html_content, output_format="json")

            news_date = datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
            news_link = entry.link
            title = html.unescape(entry.title).replace('\n', ' ')
            content = html.unescape(entry.summary).replace('\n', ' ')
            content = re.sub(r'◎공감언론 뉴시스 [\w@.]+', '', content)

            soup = BeautifulSoup(content, 'html.parser')
            cleaned_content = soup.get_text()

            news_item = {
                "newsDate": news_date,
                "newsLink": news_link,
                "title": title,
                "content": cleaned_content,
                "category": category
            }

            response = requests.post(gpt_server_url, json=news_item)
            print("서버 응답:", response.text)
            print(json.dumps(news_item, ensure_ascii=False, indent=4))

# 스케줄러 설정하기
schedule.every(30).seconds.do(scheduled_fetch)

# 무한 루프 생성해서 스케줄링 작업 주기적으로 실행
while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 61
#      59 while True:
#      60     schedule.run_pending()
# ---> 61     time.sleep(60)
#
# KeyboardInterrupt:
